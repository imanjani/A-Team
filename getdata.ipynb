# %%
from lxml import html
import requests
import pandas as pd
import html5lib

# %%
page = requests.get('https://www.fifaindex.com/teams/fifa14_13/?type=1.html')
tree = html.fromstring(page.content)

# %%
url = "https://www.fifaindex.com/teams/fifa14_13/?type=1"
url2 = "https://www.fifaindex.com/teams/fifa14_13/2/?type=1"
url3 ="http://www.fifa.com/worldcup/archive/brazil2014/matches/index.html"

# %%
header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

# %%
r = requests.get(url, headers=header)

dfs = pd.read_html(r.text)

# %%
data = dfs[0]

# %%
labels = ('u1','u2','Name','League','ATT','MID','DEF','OVR', "TR")

# %%
table1 = pd.DataFrame(data)

# %%
table1.dtypes
# Out:
# Unnamed: 0     float64
# Unnamed: 1      object
# Name            object
# League           int64
# ATT              int64
# MID              int64
# DEF              int64
# OVR            float64
# Team Rating    float64
# dtype: object

# %%
table1.columns = labels

# %%
table1
# Out:
#     u1              u2           Name  League  ATT  MID  DEF  OVR  TR
# 0  NaN           Spain  International      86   84   82   84  NaN NaN
# 1  NaN          Brazil  International      83   81   83   83  NaN NaN
# 2  NaN         Germany  International      82   84   78   83  NaN NaN
# 3  NaN       Argentina  International      85   82   79   82  NaN NaN
# 4  NaN          France  International      82   80   80   81  NaN NaN
# 5  NaN         Belgium  International      75   81   79   81  NaN NaN
# 6  NaN         England  International      85   79   78   80  NaN NaN
# 7  NaN        Portugal  International      82   79   80   80  NaN NaN
# 8  NaN           Italy  International      79   78   78   80  NaN NaN
# 9  NaN     Netherlands  International      84   76   75   79  NaN NaN
# 10 NaN          Turkey  International      76   79   76   78  NaN NaN
# 11 NaN        Colombia  International      77   78   75   77  NaN NaN
# ...

# %%
table2 = table1.drop(['u1','Name','OVR','TR'], axis=1)

# %%
table2
# Out:
#                 u2  League  ATT  MID  DEF
# 0            Spain      86   84   82   84
# 1           Brazil      83   81   83   83
# 2          Germany      82   84   78   83
# 3        Argentina      85   82   79   82
# 4           France      82   80   80   81
# 5          Belgium      75   81   79   81
# 6          England      85   79   78   80
# 7         Portugal      82   79   80   80
# 8            Italy      79   78   78   80
# 9      Netherlands      84   76   75   79
# 10          Turkey      76   79   76   78
# 11        Colombia      77   78   75   77
# 12          Russia      76   75   75   77
# 13         Uruguay      82   75   76   76
# 14           Chile      77   75   70   76
# 15   Côte d'Ivoire      77   74   74   76
# 16     Switzerland      74   76   77   76
# 17          Sweden      77   74   74   75
# 18          Poland      77   73   74   75
# 19        Cameroon      75   73   76   75
# 20  Czech Republic      73   74   73   75
# ...

# %%
r = requests.get(url2, headers=header)

dfs = pd.read_html(r.text)

# %%
data = dfs[0]

# %%
table3 = pd.DataFrame(data)

# %%
table3.columns = labels

# %%
table3 = table3.drop(['u1','Name','OVR','TR'], axis=1)

# %%
table3
# Out:
#                   u2  League  ATT  MID  DEF
# 0           Slovenia      71   73   71   73
# 1              Wales      70   74   72   73
# 2               Peru      77   69   70   72
# 3     Korea Republic      75   71   69   72
# 4            Ecuador      73   73   67   72
# 5             Norway      71   73   70   72
# 6          Venezuela      72   69   72   71
# 7   Northern Ireland      71   69   69   70
# 8          Australia      72   70   65   69
# 9              Egypt      70   67   64   69
# 10           Hungary      69   67   67   69
# 11           Finland      68   71   69   69
# 12      South Africa      65   69   69   69
# 13          Bulgaria      66   69   67   68
# 14       New Zealand      65   55   64   65
# 15           Bolivia      68   57   63   63
# 16             India      59   54   53   57

# %%
table2.append(table3, ignore_index=True)
# Out:
#                   u2  League  ATT  MID  DEF
# 0              Spain      86   84   82   84
# 1             Brazil      83   81   83   83
# 2            Germany      82   84   78   83
# 3          Argentina      85   82   79   82
# 4             France      82   80   80   81
# 5            Belgium      75   81   79   81
# 6            England      85   79   78   80
# 7           Portugal      82   79   80   80
# 8              Italy      79   78   78   80
# 9        Netherlands      84   76   75   79
# 10            Turkey      76   79   76   78
# 11          Colombia      77   78   75   77
# 12            Russia      76   75   75   77
# 13           Uruguay      82   75   76   76
# 14             Chile      77   75   70   76
# 15     Côte d'Ivoire      77   74   74   76
# 16       Switzerland      74   76   77   76
# 17            Sweden      77   74   74   75
# 18            Poland      77   73   74   75
# 19          Cameroon      75   73   76   75
# ...

# %%
r = requests.get(url3, headers=header)

dfs = pd.read_html(r.text)

# %%
dfs
# Out:
# [                                         Round of 16  \
#  0  BRAZILCHILE28 Jun 2014 - 13:00 Local time28 Ju...
#
#                                        Quarter-finals  \
#  0  BRAZILCOLOMBIA04 Jul 2014 - 17:00 Local time04...
#
#                                           Semi-finals  \
#  0  BRAZILGERMANY08 Jul 2014 - 17:00 Local time08 ...
#
#                                                 Final  \
#  0  Match for third placeBRAZILNETHERLANDS12 Jul 2...
#
#                                         Semi-finals.1  \
#  0  NETHERLANDSARGENTINA09 Jul 2014 - 17:00 Local ...
#
#                                      Quarter-finals.1  \
#  0  NETHERLANDSCOSTA RICA05 Jul 2014 - 17:00 Local...
#
#                                         Round of 16.1
#  0  NETHERLANDSMEXICO29 Jun 2014 - 13:00 Local tim...  ]

# %%
table4 = pd.DataFrame(data)

# %%
table4
# Out:
#                                                    0
# 0                                           Round...
