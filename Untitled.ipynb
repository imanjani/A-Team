# %%
import pandas as pd

# %%
newdata = pd.read_csv('new_dataset.csv', encoding = "ISO-8859-1")

# %%
# newdata = newdata[newdata['Ttl Games'] != 0]
newdata
# Out:
#        Unnamed: 0   Country  Year  Wins  Losses  Draws  Points Scored  \
# 0              43  Scotland  1915     0       0      0              0
# 1              44  Scotland  1916     0       0      0              0
# 2              45  Scotland  1917     0       0      0              0
# 3              46  Scotland  1918     0       0      0              0
# 4              47  Scotland  1919     0       0      0              0
# 5              68  Scotland  1940     0       0      0              0
# 6              69  Scotland  1941     0       0      0              0
# 7              70  Scotland  1942     0       0      0              0
# 8              71  Scotland  1943     0       0      0              0
# 9              72  Scotland  1944     0       0      0              0
# 10             73  Scotland  1945     0       0      0              0
# 11            146  Scotland  2018     0       0      0              0
# ...
